# %%
from ui import build_ui
from run import run_program
import dask
from dask.diagnostics import ProgressBar

import panel as pn
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='331727a4-8a09-42c2-ab6a-34ea1ee448ef'>
#   <div id="ea8d12c9-5046-403b-ad2a-08e9db295a72" data-root-id="331727a4-8a09-42c2-ab6a-34ea1ee448ef" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
ui = build_ui()
ui
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='85d9c21d-dd06-43e1-a745-da344c8a6c14'>
#   <div id="eb7473b5-4e5d-4770-a19c-2d71bd4772b2" data-root-id="85d9c21d-dd06-43e1-a745-da344c8a6c14" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
print(ui[0][1][0][2].value)

# %%
with ProgressBar():
    run_program(ui)
